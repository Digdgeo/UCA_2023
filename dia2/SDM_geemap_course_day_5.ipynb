# %% [markdown]
# **Enlace al Notebook del día 4 (primer día con python)**

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Digdgeo/GEE_Course_2022/blob/main/Dia4/SDM_geemap_course_day_4.ipynb)

# %%
#!pip install geemap

# %% [markdown]
# # <font color = 'red'>**GEE Lesson 10 - Reducing an Earth Engine ImageCollection**</font>

# %% [markdown]
# https://tutorials.geemap.org/ImageCollection/reducing_image_collection/

# %% [markdown]
# **Reducing an ImageCollection**
#
# To composite images in an `ImageCollection`, use `imageCollection.reduce()`. This will composite all the images in the collection to a single image representing, for example, the min, max, mean or standard deviation of the images. (See the Reducers section for more information about reducers). For example, to create a median value image from a collection:

# %%
import ee
import geemap

ee.Authenticate()
ee.Initialize()
# Out:
# To authorize access needed by Earth Engine, open the following URL in a web browser and follow the instructions. If the web browser does not start automatically, please manually browse the URL below.
#
#     https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=bOGyDzREgSFawv-OU-5BjgwrSyLP6h-4XzE16-g3iUA&tc=yVgCq5Z8i-4hYBgeIgB7aHc6uuoBh-65cw9iIbkYb_E&cc=Q7scQvMLuDcNmIr6h1W7and4rMfYPBL8i42mbbaLq5E
#
# The authorization workflow will generate a code, which you should paste in the box below.
# Enter verification code: 4/1AX4XfWiDybEcLufo6zcZAYcDxsRqHykwAUuMaJ6BojJXbP71O0kWYF4IPV4
#
# Successfully saved authorization token.

# %%
Map = geemap.Map()
Map
# Out:
# Map(center=[20, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(Togg…

# %% [markdown]
# ## Compute a median image

# %%
# Load a Landsat 8 collection for a single path-row.
collection = ee.ImageCollection('LANDSAT/LC08/C01/T1_TOA') \
    .filter(ee.Filter.eq('WRS_PATH', 202)) \
    .filter(ee.Filter.eq('WRS_ROW', 34)) \
    .filterDate('2021-01-01', '2021-12-31')

# Compute a median image and display.
median = collection.median()
Map.setCenter(-6.15, 37, 12)
Map.addLayer(median, {'bands': ['B4',  'B3',  'B2'], 'max': 0.3}, 'median')

# %%
collection.size().getInfo()
# Out:
# 21

# %%
collection.aggregate_array("system:id").getInfo()
# Out:
# ['LANDSAT/LC08/C01/T1_TOA/LC08_202034_20210103',
#  'LANDSAT/LC08/C01/T1_TOA/LC08_202034_20210119',
#  'LANDSAT/LC08/C01/T1_TOA/LC08_202034_20210204',
#  'LANDSAT/LC08/C01/T1_TOA/LC08_202034_20210220',
#  'LANDSAT/LC08/C01/T1_TOA/LC08_202034_20210324',
#  'LANDSAT/LC08/C01/T1_TOA/LC08_202034_20210409',
#  'LANDSAT/LC08/C01/T1_TOA/LC08_202034_20210425',
#  'LANDSAT/LC08/C01/T1_TOA/LC08_202034_20210511',
#  'LANDSAT/LC08/C01/T1_TOA/LC08_202034_20210612',
#  'LANDSAT/LC08/C01/T1_TOA/LC08_202034_20210628',
#  'LANDSAT/LC08/C01/T1_TOA/LC08_202034_20210714',
#  'LANDSAT/LC08/C01/T1_TOA/LC08_202034_20210730',
#  'LANDSAT/LC08/C01/T1_TOA/LC08_202034_20210815',
#  'LANDSAT/LC08/C01/T1_TOA/LC08_202034_20210831',
#  'LANDSAT/LC08/C01/T1_TOA/LC08_202034_20210916',
#  'LANDSAT/LC08/C01/T1_TOA/LC08_202034_20211002',
#  'LANDSAT/LC08/C01/T1_TOA/LC08_202034_20211018',
#  'LANDSAT/LC08/C01/T1_TOA/LC08_202034_20211103',
#  'LANDSAT/LC08/C01/T1_TOA/LC08_202034_20211119',
#  'LANDSAT/LC08/C01/T1_TOA/LC08_202034_20211205',
#  'LANDSAT/LC08/C01/T1_TOA/LC08_202034_20211221']

# %% [markdown]
# At each location in the output image, in each band, the pixel value is the median of all unmasked pixels in the input imagery (the images in the collection). In the previous example, median() is a convenience method for the following call:

# %%
# Reduce the collection with a median reducer.
median = collection.reduce(ee.Reducer.median())

# Display the median image.
Map.addLayer(median,
             {'bands': ['B4_median',  'B3_median',  'B2_median'], 'max': 0.3},
             'also median')
Map
# Out:
# Map(bottom=408437.0, center=[37, -6.15], controls=(WidgetControl(options=['position', 'transparent_bg'], widge…

# %% [markdown]
# ## Create an image composite

# %%
peninsula = ee.FeatureCollection('projects/ee-digdgeografo/assets/peninsula_iberica')
#Map.addLayer(peninsula)

# %%
collection = ee.ImageCollection('LANDSAT/LC08/C01/T1_TOA') \
    .filterBounds(peninsula) \
    .filterDate('2020-01-01', '2021-01-01')

# %%
collection.size().getInfo()
# Out:
# 611

# %%
spain = peninsula.filter(ee.Filter.eq("ADM0_A3", "ESP"))
portugal = peninsula.filter(ee.Filter.eq("ADM0_A3", "PRT"))
#Map.addLayer(portugal, {}, "Portugal")

# %%
image = collection.median().clip(spain)
Map.addLayer(image, {'bands': ['B4',  'B3',  'B2'], 'max': 0.3}, 'Landsat 2020')

# %% [markdown]
# #<font color = 'red'>**GEE Lesson 11 - Using the map function with Earth Engine Image Collection**</font>

# %% [markdown]
# https://tutorials.geemap.org/ImageCollection/mapping_over_image_collection/

# %%
Map = geemap.Map()

# %%
def minus1000(num):
    result = ee.Number(num).subtract(1000)
    return result

# %%
result = minus1000(2000)
print(result.getInfo())
# Out:
# 1000

# %% [markdown]
# ## Apply the map function

# %%
years = ee.List.sequence(2000, 2010)
print(years.getInfo())
# Out:
# [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010]

# %%
results = years.map(minus1000)
print(results.getInfo())
# Out:
# [1000, 1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008, 1009, 1010]

# %% [markdown]
# ## Use anonymous/lambda function

# %%
years = ee.List.sequence(2000, 2010)

results = years.map(lambda x: ee.Number(x).subtract(1000))
print(results.getInfo())
# Out:
# [1000, 1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008, 1009, 1010]

# %% [markdown]
# ## Filter an ImageCollection

# %%
roi = ee.Geometry.Point(-5.92, 36.96)  # Knoxville, Tennessee

collection = ee.ImageCollection('LANDSAT/LC08/C01/T1_SR') \
    .filterBounds(roi) \
    .filterDate("2019-01-01", "2020-01-01") \
    .sort("CLOUD_COVER")

print(collection.size().getInfo())
# Out:
# 25

# %%
image = collection.first()

# %%
image.getInfo()
# Out:
# {'bands': [{'crs': 'EPSG:32629',
#    'crs_transform': [30, 0, 632985, 0, -30, 4266315],
#    'data_type': {'max': 32767,
#     'min': -32768,
#     'precision': 'int',
#     'type': 'PixelType'},
#    'dimensions': [7571, 7711],
#    'id': 'B1'},
#   {'crs': 'EPSG:32629',
#    'crs_transform': [30, 0, 632985, 0, -30, 4266315],
#    'data_type': {'max': 32767,
#     'min': -32768,
#     'precision': 'int',
#     'type': 'PixelType'},
#    'dimensions': [7571, 7711],
#    'id': 'B2'},
#   {'crs': 'EPSG:32629',
#    'crs_transform': [30, 0, 632985, 0, -30, 4266315],
#    'data_type': {'max': 32767,
#     'min': -32768,
#     'precision': 'int',
#     'type': 'PixelType'},
#    'dimensions': [7571, 7711],
#    'id': 'B3'},
#   {'crs': 'EPSG:32629',
#    'crs_transform': [30, 0, 632985, 0, -30, 4266315],
#    'data_type': {'max': 32767,
#     'min': -32768,
#     'precision': 'int',
#     'type': 'PixelType'},
#    'dimensions': [7571, 7711],
#    'id': 'B4'},
#   {'crs': 'EPSG:32629',
#    'crs_transform': [30, 0, 632985, 0, -30, 4266315],
#    'data_type': {'max': 32767,
#     'min': -32768,
#     'precision': 'int',
#     'type': 'PixelType'},
#    'dimensions': [7571, 7711],
#    'id': 'B5'},
#   {'crs': 'EPSG:32629',
#    'crs_transform': [30, 0, 632985, 0, -30, 4266315],
#    'data_type': {'max': 32767,
#     'min': -32768,
#     'precision': 'int',
#     'type': 'PixelType'},
#    'dimensions': [7571, 7711],
#    'id': 'B6'},
#   {'crs': 'EPSG:32629',
#    'crs_transform': [30, 0, 632985, 0, -30, 4266315],
#    'data_type': {'max': 32767,
#     'min': -32768,
#     'precision': 'int',
#     'type': 'PixelType'},
#    'dimensions': [7571, 7711],
#    'id': 'B7'},
#   {'crs': 'EPSG:32629',
#    'crs_transform': [30, 0, 632985, 0, -30, 4266315],
#    'data_type': {'max': 32767,
#     'min': -32768,
#     'precision': 'int',
#     'type': 'PixelType'},
#    'dimensions': [7571, 7711],
#    'id': 'B10'},
#   {'crs': 'EPSG:32629',
#    'crs_transform': [30, 0, 632985, 0, -30, 4266315],
#    'data_type': {'max': 32767,
#     'min': -32768,
#     'precision': 'int',
#     'type': 'PixelType'},
#    'dimensions': [7571, 7711],
#    'id': 'B11'},
#   {'crs': 'EPSG:32629',
#    'crs_transform': [30, 0, 632985, 0, -30, 4266315],
#    'data_type': {'max': 255,
#     'min': 0,
#     'precision': 'int',
#     'type': 'PixelType'},
#    'dimensions': [7571, 7711],
#    'id': 'sr_aerosol'},
#   {'crs': 'EPSG:32629',
#    'crs_transform': [30, 0, 632985, 0, -30, 4266315],
#    'data_type': {'max': 65535,
#     'min': 0,
#     'precision': 'int',
#     'type': 'PixelType'},
#    'dimensions': [7571, 7711],
#    'id': 'pixel_qa'},
#   {'crs': 'EPSG:32629',
#    'crs_transform': [30, 0, 632985, 0, -30, 4266315],
#    'data_type': {'max': 65535,
#     'min': 0,
#     'precision': 'int',
#     'type': 'PixelType'},
#    'dimensions': [7571, 7711],
#    'id': 'radsat_qa'}],
#  'id': 'LANDSAT/LC08/C01/T1_SR/LC08_202034_20190810',
#  'properties': {'CLOUD_COVER': 0.01,
#   'CLOUD_COVER_LAND': 0.01,
#   'EARTH_SUN_DISTANCE': 1.01373,
#   'ESPA_VERSION': '2_23_0_1b',
#   'GEOMETRIC_RMSE_MODEL': 7.863,
#   'GEOMETRIC_RMSE_MODEL_X': 5.493,
#   'GEOMETRIC_RMSE_MODEL_Y': 5.626,
#   'IMAGE_QUALITY_OLI': 9,
#   'IMAGE_QUALITY_TIRS': 9,
#   'LANDSAT_ID': 'LC08_L1TP_202034_20190810_20190820_01_T1',
#   'LEVEL1_PRODUCTION_DATE': 1566303725000,
#   'PIXEL_QA_VERSION': 'generate_pixel_qa_1.6.0',
#   'SATELLITE': 'LANDSAT_8',
#   'SENSING_TIME': '2019-08-10T11:02:39.9555230Z',
#   'SOLAR_AZIMUTH_ANGLE': 132.630096,
#   'SOLAR_ZENITH_ANGLE': 29.232498,
#   'SR_APP_VERSION': 'LaSRC_1.3.0',
#   'WRS_PATH': 202,
#   'WRS_ROW': 34,
#   'system:asset_size': 630995513,
#   'system:footprint': {'coordinates': [[-6.863602171483663, 38.49926286098679],
#     [-6.994162278495938, 38.52266361816671],
#     [-6.996281654615721, 38.52269988324879],
#     [-6.999540827168556, 38.511727444061734],
#     [-7.245730808020996, 37.65960436907686],
#     [-7.487111103172097, 36.80268810312814],
#     [-7.463028919497432, 36.79826751033394],
#     [-7.2882242340565915, 36.76613466786529],
#     [-5.5978116303317265, 36.440821002248164],
#     [-5.461030523198724, 36.41333995288387],
#     [-5.456189455894105, 36.42819348475368],
#     [-5.215232354110658, 37.20707795344896],
#     [-5.188997542063192, 37.290830935875654],
#     [-5.159976408399039, 37.383396506317425],
#     [-5.096064204396052, 37.58652630755988],
#     [-5.0303351172915685, 37.7946083514138],
#     [-4.995825393838432, 37.903891227180175],
#     [-4.932303508056023, 38.105116565292356],
#     [-4.923654869739747, 38.13259089301934],
#     [-5.237150116469687, 38.19424905412472],
#     [-6.359252539517677, 38.40734093980992],
#     [-6.863602171483663, 38.49926286098679]],
#    'type': 'LinearRing'},
#   'system:index': 'LC08_202034_20190810',
#   'system:time_end': 1565434959955,
#   'system:time_start': 1565434959955},
#  'type': 'Image',
#  'version': 1566762591950601}

# %%
geemap.image_props(image).getInfo()
# Out:
# {'CLOUD_COVER': 0.01,
#  'CLOUD_COVER_LAND': 0.01,
#  'EARTH_SUN_DISTANCE': 1.01373,
#  'ESPA_VERSION': '2_23_0_1b',
#  'GEOMETRIC_RMSE_MODEL': 7.863,
#  'GEOMETRIC_RMSE_MODEL_X': 5.493,
#  'GEOMETRIC_RMSE_MODEL_Y': 5.626,
#  'IMAGE_DATE': '2019-08-10',
#  'IMAGE_QUALITY_OLI': 9,
#  'IMAGE_QUALITY_TIRS': 9,
#  'LANDSAT_ID': 'LC08_L1TP_202034_20190810_20190820_01_T1',
#  'LEVEL1_PRODUCTION_DATE': 1566303725000,
#  'NOMINAL_SCALE': 30,
#  'PIXEL_QA_VERSION': 'generate_pixel_qa_1.6.0',
#  'SATELLITE': 'LANDSAT_8',
#  'SENSING_TIME': '2019-08-10T11:02:39.9555230Z',
#  'SOLAR_AZIMUTH_ANGLE': 132.630096,
#  'SOLAR_ZENITH_ANGLE': 29.232498,
#  'SR_APP_VERSION': 'LaSRC_1.3.0',
#  'WRS_PATH': 202,
#  'WRS_ROW': 34,
#  'system:asset_size': '630.995513 MB',
#  'system:band_names': ['B1',
#   'B2',
#   'B3',
#   'B4',
#   'B5',
#   'B6',
#   'B7',
#   'B10',
#   'B11',
#   'sr_aerosol',
#   'pixel_qa',
#   'radsat_qa'],
#  'system:id': 'LANDSAT/LC08/C01/T1_SR/LC08_202034_20190810',
#  'system:index': 'LC08_202034_20190810',
#  'system:time_end': '2019-08-10 11:02:39',
#  'system:time_start': '2019-08-10 11:02:39',
#  'system:version': 1566762591950601}

# %%
collection.aggregate_array("CLOUD_COVER").getInfo()
# Out:
# [0.01,
#  0.01,
#  0.03,
#  0.05,
#  0.37,
#  0.83,
#  1.06,
#  1.11,
#  1.33,
#  2.29,
#  2.39,
#  2.47,
#  2.68,
#  4.25,
#  4.62,
#  7.06,
#  7.74,
#  19.76,
#  29.08,
#  29.3,
#  36.03,
#  48.63,
#  58.58,
#  66.22,
#  98.19]

# %%
#Map = geemap.Map()
vis_params = {
    'bands': ['B5', 'B4', 'B3'],
    'min': 0, 
    'max': 3000,
    'gamma': 1.0
}

Map.addLayer(image, vis_params, "First image")
Map.centerObject(image)
Map
# Out:
# Map(center=[20, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(Togg…

# %% [markdown]
# ## Select the best image each year

# %%
roi = ee.Geometry.Point(-5.99, 36.96)

def best_image(year):
    start_date = ee.Date.fromYMD(year, 1, 1)
    end_date = start_date.advance(1, 'year')
    
    image = ee.ImageCollection('LANDSAT/LC08/C01/T1_SR') \
        .filterBounds(roi) \
        .filterDate(start_date, end_date) \
        .sort("CLOUD_COVER") \
        .first()
    
    return image

# %%
start_year = 2013
end_year = 2020
years = ee.List.sequence(start_year, end_year)
year_list = years.getInfo()
print(year_list)
# Out:
# [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]

# %%
images = years.map(best_image)

# %%
count = images.size().getInfo()
print(count)
# Out:
# 8

# %%
ee.ImageCollection(images).aggregate_array("CLOUD_COVER").getInfo()
# Out:
# [0, 0, 0.01, 0, 0, 0, 0.01, 0.09]

# %%
for index in range(0, count):
    image = ee.Image(images.get(index))
    layer_name = "Image " + str(year_list[index])
    #print(layer_name)
    Map.addLayer(image, vis_params, layer_name, False)

# %%
#Map = geemap.Map(height=1200)
Map
# Out:
# Map(center=[20, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(Togg…

# %% [markdown]
# ## Set image properties

# %%
collection = ee.ImageCollection(images)

# %%
collection.aggregate_array("system:time_start").getInfo()
# Out:
# [1374663871570,
#  1407841356543,
#  1438254130360,
#  1470049354510,
#  1501844552565,
#  1537786934040,
#  1565434959955,
#  1604142172552]

# %%
collection = collection.map(lambda img: img.set({"DATE": ee.Date(img.get("system:time_start")).format("YYYY-MM-dd")}))

# %%
collection.aggregate_array("DATE").getInfo()
# Out:
# ['2013-07-24',
#  '2014-08-12',
#  '2015-07-30',
#  '2016-08-01',
#  '2017-08-04',
#  '2018-09-24',
#  '2019-08-10',
#  '2020-10-31']

# %% [markdown]
# # <font color = 'red'>**GEE Lesson 12. Creating time-series cloud-free image composite**</font>

# %% [markdown]
# https://tutorials.geemap.org/ImageCollection/cloud_free_composite/

# %%
Map = geemap.Map(height=1000)
Map
# Out:
# Map(center=[20, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(Togg…

# %%
years = ee.List.sequence(2013, 2020)
years.getInfo()
# Out:
# [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]

# %%
def yearly_image(year):
    
    start_date = ee.Date.fromYMD(year, 1, 1) 
    end_date = start_date.advance(1, "year")
    
    collection = ee.ImageCollection('LANDSAT/LC08/C01/T1') \
        .filterDate(start_date, end_date) \
        .filterBounds(portugal) 
    
    image =  ee.Algorithms.Landsat.simpleComposite(collection).clipToCollection(portugal)

    return image

# %%
images = years.map(yearly_image)

# %%
vis_params = {
    'bands': ['B6', 'B5', 'B2'],
    'min': 0, 
    'max': 150,
    'gamma': 1.0
}

for index in range(0, 8):
    image = ee.Image(images.get(index))
    layer_name = "Image " + str(index + 2013)
    Map.addLayer(image, vis_params, layer_name)

# %% [markdown]
# # <font color='red'>**GEE Lesson 13 - Visualizing Earth Engine time-series images**</font>

# %% [markdown]
# https://tutorials.geemap.org/ImageCollection/visualizing_time_series/

# %% [markdown]
# ## Visualizing weather data

# %%
Map = geemap.Map()

collection = ee.ImageCollection('NOAA/GFS0P25') \
  .filterDate('2021-07-22', '2021-07-23') \
  .limit(24) \
  .select('temperature_2m_above_ground')

vis_params = {
  'min': -40.0,
  'max': 35.0,
  'palette': ['blue', 'purple', 'cyan', 'green', 'yellow', 'red']
}

first_image = collection.first()

Map.addLayer(first_image, vis_params, "First image")
Map.setCenter(-0.3490, 25.7900, 2)
Map
# Out:
# Map(center=[25.79, -0.349], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(childr…

# %%
image = collection.toBands()
Map.addLayer(image, {}, "Time series", False)

# %%
labels = [str(n).zfill(2) + ":00" for n in range(0, 24)]
labels
# Out:
# ['00:00',
#  '01:00',
#  '02:00',
#  '03:00',
#  '04:00',
#  '05:00',
#  '06:00',
#  '07:00',
#  '08:00',
#  '09:00',
#  '10:00',
#  '11:00',
#  '12:00',
#  '13:00',
#  '14:00',
#  '15:00',
#  '16:00',
#  '17:00',
#  '18:00',
#  '19:00',
#  '20:00',
#  '21:00',
#  '22:00',
#  '23:00']

# %%
Map.add_time_slider(collection, vis_params, labels=labels, time_interval=1)
Map
# Out:
# Map(bottom=6788.0, center=[35.02999636902566, -0.8020019531250001], controls=(WidgetControl(options=['position…

# %% [markdown]
# ## Visualizing vegetation data

# %%
Map = geemap.Map()

collection = ee.ImageCollection('MODIS/MCD43A4_006_NDVI') \
                  .filter(ee.Filter.date('2018-04-01', '2018-05-01')) \
                  .select("NDVI")\

vis_params = {
  'min': 0.0,
  'max': 1.0,
  'palette': [
    'FFFFFF', 'CE7E45', 'DF923D', 'F1B555', 'FCD163', '99B718', '74A901',
    '66A000', '529400', '3E8601', '207401', '056201', '004C00', '023B01',
    '012E01', '011D01', '011301'
  ],
}

first_image = collection.first()

Map.addLayer(first_image, vis_params, "First image")
Map.setCenter(-7.03125, 31.0529339857, 2)
Map
# Out:
# Map(center=[31.0529339857, -7.03125], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=H…

# %%
image = collection.toBands()
Map.addLayer(image, {}, "Time series", False)

# %%
labels = collection.aggregate_array("system:index").getInfo()
Map.add_time_slider(collection, vis_params, labels=labels, time_interval=1)

# %% [markdown]
# ## Visualizing Landsat imagery

# %%
Map = geemap.Map()

bands = ['B1', 'B2', 'B3', 'B4', 'B5', 'B7']
image = ee.Image('LE7_TOA_5YEAR/1999_2003').select(bands)
vis_params = {'min': 20, 'max': 200, 'gamma': 2.0}

Map.add_time_slider(image, vis_params, labels=bands, time_interval=1)

Map
# Out:
# Map(center=[20, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(Togg…

# %% [markdown]
# #<font color = 'red'>**GEE Lesson 14 - Exporting Earth Engine data**</font>

# %% [markdown]
# https://tutorials.geemap.org/AssetManagement/export_data/

# %%
import os
from geemap.datasets import DATA

# %%
Map = geemap.Map()

# %% [markdown]
# ## Set an output directory

# %%
out_dir = os.path.expanduser("~/Downloads")

if not os.path.exists(out_dir):
    os.makedirs(out_dir)

# %%
out_dir = os.path.expanduser("~/Downloads")
filename = os.path.join(out_dir, 'landsat.tif')
print(filename)
# Out:
# /root/home/diego/Downloads/landsat.tif

# %% [markdown]
# ## Export an ee.FeatureCollection

# %%
fc = ee.FeatureCollection('users/giswqs/public/countries')

# %%
Map.addLayer(fc, {}, "Countries")
Map.centerObject(fc)
Map
# Out:
# Map(center=[20, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(Togg…

# %% [markdown]
# Export data to a local computer

# %%
out_shp = os.path.join(out_dir, "countries.shp")
geemap.ee_export_vector(fc, out_shp, verbose=True)
# Out:
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/tables/af2cd31629bab2fcc5007bd374c36321-ea871f5f0d8e284d9a8b56b67cf1d9ba:getFeatures
# Please wait ...
# Data downloaded to /home/diego/Descargas/geemapDownloads/countries.shp

# %% [markdown]
# Export data to Google Drive

# %%
geemap.ee_export_vector_to_drive(fc, description="countries", folder="export")
# Out:
# Exporting countries...

# %% [markdown]
# ## Export an ee.Image

# %%
image = ee.Image('LE7_TOA_5YEAR/1999_2003')

landsat_vis = {
    'bands': ['B4', 'B3', 'B2'], 
    'gamma': 1.7
}
Map.addLayer(image, landsat_vis, "LE7_TOA_5YEAR/1999_2003", True, 1)
Map
# Out:
# Map(bottom=6720.0, center=[36.23984280222428, -354.62768554687506], controls=(WidgetControl(options=['position…

# %%
out_dir = os.path.expanduser("~/Downloads")
filename = os.path.join(out_dir, 'landsat.tif')
#print(filename)

# %% [markdown]
# ### Exporting all bands as one single image

# %%
# Draw any shapes on the map using the Drawing tools before executing this code block
roi = Map.user_roi

# %%
roi.getInfo()
# Out:
# {'coordinates': [[[-369.540253, 39.300831],
#    [-369.540253, 39.443087],
#    [-369.273148, 39.443087],
#    [-369.273148, 39.300831],
#    [-369.540253, 39.300831]]],
#  'geodesic': False,
#  'type': 'Polygon'}

# %%
image_clip = image.clip(roi)

# %%
Map.addLayer(image_clip, landsat_vis, "image")

# %%
geemap.ee_export_image(image_clip, filename=filename, scale=90, region=roi, file_per_band=False)
# Out:
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/aa3eda3b1a0809681ee16fe99089ec8c-b10b17e7c4a01f8aaa48e25db81622f6:getPixels
# Please wait ...
# Data downloaded to /home/diego/Descargas/geemapDownloads/landsat.tif

# %% [markdown]
# ### Exporting each band as one image

# %%
geemap.ee_export_image(image, filename=filename, scale=90, region=roi, file_per_band=True)
# Out:
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/69c5822c844f9a0740379e5a065a003c-6108ab7aef0044d781123624e8aec10a:getPixels
# Please wait ...
# Data downloaded to /root/Downloads

# %% [markdown]
# ### Export an image to Google Drive

# %%
geemap.ee_export_image_to_drive(image_clip, description='landsat', folder='export', region=roi, scale=30)
# Out:
# Exporting landsat ...

# %% [markdown]
# ## Download an ee.ImageCollection

# %%
loc = ee.Geometry.Point(-99.2222, 46.7816)
collection = ee.ImageCollection('USDA/NAIP/DOQQ') \
    .filterBounds(loc) \
    .filterDate('2008-01-01', '2020-01-01') \
    .filter(ee.Filter.listContains("system:band_names", "N"))

# %%
out_dir = os.path.expanduser('~/Downloads')

# %%
collection.aggregate_array('system:index').getInfo()
# Out:
# ['m_4609915_sw_14_060_20180902_20181213',
#  'm_4609915_sw_14_060_20190626',
#  'm_4609915_sw_14_1_20090818',
#  'm_4609915_sw_14_1_20100629',
#  'm_4609915_sw_14_1_20120714',
#  'm_4609915_sw_14_1_20140901',
#  'm_4609915_sw_14_1_20150926',
#  'm_4609915_sw_14_h_20160704',
#  'm_4609915_sw_14_h_20170703']

# %%
geemap.ee_export_image_collection(collection, out_dir=out_dir)
# Out:
# Total number of images: 9
#
# Exporting 1/9: m_4609915_sw_14_060_20180902_20181213.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/12dba27394c3260fc731c0d6229e43a5-f8ceb3e7044bb624c98093bc374fa7e7:getPixels
# Please wait ...
# Data downloaded to /root/Downloads/m_4609915_sw_14_060_20180902_20181213.tif
#
#
# Exporting 2/9: m_4609915_sw_14_060_20190626.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/a05dd6d80c920403e8f1f943da8c4174-2e81c6842dbc3cb894f9b426689b983e:getPixels
# Please wait ...
# Data downloaded to /root/Downloads/m_4609915_sw_14_060_20190626.tif
#
#
# Exporting 3/9: m_4609915_sw_14_1_20090818.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/e0218e3dbca864608a201086538782b5-a8791584bc933c3369af0a29a4293a32:getPixels
# Please wait ...
# Data downloaded to /root/Downloads/m_4609915_sw_14_1_20090818.tif
#
#
# Exporting 4/9: m_4609915_sw_14_1_20100629.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/e8b801d6cba914811034b6a836fa64e8-8e4d4047610181e5accabf4abe9c9923:getPixels
# Please wait ...
# Data downloaded to /root/Downloads/m_4609915_sw_14_1_20100629.tif
#
#
# Exporting 5/9: m_4609915_sw_14_1_20120714.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/a2835ac668b547edc38f2c74320168d8-a4c8947765bfceebc1077a33ca056928:getPixels
# Please wait ...
# Data downloaded to /root/Downloads/m_4609915_sw_14_1_20120714.tif
#
#
# Exporting 6/9: m_4609915_sw_14_1_20140901.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/dfc26d0ec2aa00709a488938a348c954-90d11766997b4a06643bcc92184c7181:getPixels
# Please wait ...
# Data downloaded to /root/Downloads/m_4609915_sw_14_1_20140901.tif
#
#
# Exporting 7/9: m_4609915_sw_14_1_20150926.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/a3f09592597bb46998d6ca0905a1b1e2-5cf2db805a49286f0964dd86ffd5e4a8:getPixels
# Please wait ...
# Data downloaded to /root/Downloads/m_4609915_sw_14_1_20150926.tif
#
#
# Exporting 8/9: m_4609915_sw_14_h_20160704.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/0df29ebae58261ebc7edbe5743f785f7-12938b029c3eb6b212bb3d4e2e7110e5:getPixels
# Please wait ...
# Data downloaded to /root/Downloads/m_4609915_sw_14_h_20160704.tif
#
#
# Exporting 9/9: m_4609915_sw_14_h_20170703.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/b8e7221f77039b3b23cd347962c1a654-a5b4c0f64f492d48a5f0cb98fbc94601:getPixels
# Please wait ...
# Data downloaded to /root/Downloads/m_4609915_sw_14_h_20170703.tif

# %%
geemap.ee_export_image_collection_to_drive(collection, folder='export', scale=10)
# Out:
# Total number of images: 9
#
# Exporting m_4609915_sw_14_060_20180902_20181213 ...
# Exporting m_4609915_sw_14_060_20190626 ...
# Exporting m_4609915_sw_14_1_20090818 ...
# Exporting m_4609915_sw_14_1_20100629 ...
# Exporting m_4609915_sw_14_1_20120714 ...
# Exporting m_4609915_sw_14_1_20140901 ...
# Exporting m_4609915_sw_14_1_20150926 ...
# Exporting m_4609915_sw_14_h_20160704 ...
# Exporting m_4609915_sw_14_h_20170703 ...

# %% [markdown]
# ## Extract pixels as a Numpy array

# %%
import numpy as np
import matplotlib.pyplot as plt

img = ee.Image('LANDSAT/LC08/C01/T1_SR/LC08_038029_20180810') \
  .select(['B4', 'B5', 'B6'])

aoi = ee.Geometry.Polygon(
  [[[-110.8, 44.7],
    [-110.8, 44.6],
    [-110.6, 44.6],
    [-110.6, 44.7]]], None, False)

rgb_img = geemap.ee_to_numpy(img, region=aoi)
print(rgb_img.shape)
# Out:
# (373, 531, 3)

# %% [markdown]
# # <font color = 'red'>**GEE Lesson 15 - Styling Earth Engine vector data**</font>

# %% [markdown]
# https://tutorials.geemap.org/FeatureCollection/vector_styling/

# %%
Map = geemap.Map()

Map.addLayer(fc, {}, "Countries")
Map
# Out:
# Map(center=[20, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(Togg…

# %% [markdown]
# ## Use Image.paint()

# %%
Map = geemap.Map()

image = ee.Image().paint(fc, 0, 1)

Map.addLayer(image, {'palette': 'red'}, "Countries")
Map
# Out:
# Map(center=[20, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(Togg…

# %% [markdown]
# ## Use FeatureCollection.style()

# %%
Map = geemap.Map()

style = {'color': '0000ffff', 'width': 4, 'lineType': 'solid', 'fillColor': '00000080'}

Map.addLayer(fc.style(**style), {}, "US States")
Map
# Out:
# Map(center=[20, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(Togg…

# %% [markdown]
# ## Use add_styled_vector()

# %%
Map = geemap.Map()

vis_params = {
    'color': '000000', 
    'colorOpacity': 1,
    'pointSize': 3,
    'pointShape': 'circle',
    'width': 2,
    'lineType': 'solid', 
    'fillColorOpacity': 0.75    
}

palette = ['006633', 'E5FFCC', '662A00', 'D8D8D8', 'F5F5F5']

Map.add_styled_vector(fc, column="name", palette=palette, layer_name="Styled vector", **vis_params)
Map
# Out:
# Map(center=[20, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(Togg…

# %%
import geemap.colormaps as cm

# %%
Map = geemap.Map()


vis_params = {
    'color': '000000', 
    'colorOpacity': 1,
    'pointSize': 3,
    'pointShape': 'circle',
    'width': 2,
    'lineType': 'dotted', 
    'fillColorOpacity': 0.66    
}

palette = list(cm.palettes.gist_earth.n12)

Map.add_styled_vector(fc, column="name", palette=palette, layer_name="Styled vector", **vis_params)
Map
# Out:
# Map(center=[20, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(Togg…

# %% [markdown]
# ## Use interactive GUI

# %%
Map = geemap.Map()

Map.addLayer(fc, {}, "Countries")
Map
# Out:
# Map(center=[20, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(Togg…

# %% [markdown]
# # <font color = 'red'>**GEE Lesson 16 - Extracting time-series pixel values from Earth Engine Image**</font>

# %% [markdown]
# https://tutorials.geemap.org/AssetManagement/extract_values/

# %%
Map = geemap.Map()
Map
# Out:
# Map(center=[20, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(Togg…

# %%
landsat7 = ee.Image('LE7_TOA_5YEAR/1999_2003') \
    .select([0, 1, 2, 3, 4, 6])
landsat_vis = {
    'bands': ['B4', 'B3', 'B2'], 
    'gamma': 1.7
}
Map.addLayer(landsat7, landsat_vis, "LE7_TOA_5YEAR/1999_2003")

Map.set_plot_options(add_marker_cluster=True)

# %% [markdown]
# ### Export pixel values to shapefile/csv

# %%
out_dir = os.path.expanduser('~/Downloads')
# out_csv = os.path.join(out_dir, 'points.csv')
out_shp = os.path.join(out_dir, 'points.shp')

# %%
Map.extract_values_to_points(out_shp)
# Out:
# The shapefile has been saved to: /root/Downloads/points.shp

# %% [markdown]
# ## Interactive Region Reduction

# %%
import geemap.colormaps as cm

# %%
m = geemap.Map()

# %%
collection = ee.ImageCollection('MODIS/006/MOD13A2') \
    .filterDate('2015-01-01', '2019-12-31') \
    .select('NDVI')

# Convert the image collection to an image.
image = collection.toBands()

palette = cm.palettes.ndvi

ndvi_vis = {
  'min': 0.0,
  'max': 9000.0,
  'palette': palette
}

m.addLayer(image, {}, 'MODIS NDVI Time-series')
m.addLayer(image.select(0), ndvi_vis, 'MODIS NDVI VIS')

m
# Out:
# Map(bottom=1873.0, center=[38.47939467327645, 11.293945312500002], controls=(WidgetControl(options=['position'…

# %%
m.set_plot_options(add_marker_cluster=True, marker=None)
m.roi_reducer = ee.Reducer.mean()

# %% [markdown]
# ### Export data

# %%
out_dir = os.path.expanduser('~/Downloads')
# out_csv = os.path.join(out_dir, 'points.csv')
out_shp = os.path.join(out_dir, 'ndvi.shp')
m.extract_values_to_points(out_shp)
# Out:
# The shapefile has been saved to: /root/Downloads/ndvi.shp

# %% [markdown]
# ## Creating training samples

# %%
geemap.show_youtube("https://youtu.be/VWh5PxXPZw0")
# Out:
# Output(layout=Layout(width='815px'))

# %%
Map = geemap.Map()
Map
# Out:
# Map(center=[20, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(Togg…

# %%
Map.user_rois.getInfo()

# %%
out_dir = os.path.expanduser('~/Downloads')
out_shp = os.path.join(out_dir, 'collections_sample.shp')

# %%
geemap.ee_to_shp(Map.user_rois, out_shp)
# Out:
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/tables/b2ea8c319fab05841dfa0f417ebd84e3-36663c03e77459c3fd615843d216d72e:getFeatures
# Please wait ...
# Data downloaded to /root/Downloads/collections_sample.shp

# %% [markdown]
# ## <font color = 'red'>**GEE Lesson 18. Computing zonal statistics with Google Earth Engine**</font>

# %% [markdown]
# https://tutorials.geemap.org/Analysis/zonal_statistics/

# %%
Map = geemap.Map()
Map
# Out:
# Map(center=[20, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(Togg…

# %%
# Add Earth Engine dataset
dem = ee.Image('USGS/SRTMGL1_003')

# Set visualization parameters.
dem_vis = {
  'min': 0,
  'max': 4000,
  'palette': ['006633', 'E5FFCC', '662A00', 'D8D8D8', 'F5F5F5']}

# Add Earth Engine DEM to map
Map.addLayer(dem, dem_vis, 'SRTM DEM')

# Add Landsat data to map
landsat = ee.Image('LE7_TOA_5YEAR/1999_2003')

landsat_vis = {
    'bands': ['B4', 'B3', 'B2'], 
    'gamma': 1.4
}
Map.addLayer(landsat, landsat_vis, "Landsat", False)

Map.addLayer(fc, {}, 'countries')

# %% [markdown]
# ## Compute zonal statistics for one image

# %%
out_dir = os.path.expanduser('~/Downloads')
if not os.path.exists(out_dir):
    os.makedirs(out_dir)

# %%
out_dem_stats = os.path.join(out_dir, 'dem_stats.csv')  

# Allowed output formats: csv, shp, json, kml, kmz
# Allowed statistics type: MEAN, MAXIMUM, MINIMUM, MEDIAN, STD, MIN_MAX, VARIANCE, SUM
geemap.zonal_statistics(dem, fc, out_dem_stats, statistics_type='MEAN', scale=1000)
# Out:
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/tables/2b33c816536d4657affbb66a9434dd89-b08882c89d08a34bd8adb1e6cf642af4:getFeatures
# Please wait ...
# Data downloaded to /root/Downloads/dem_stats.csv

# %%
out_landsat_stats = os.path.join(out_dir, 'landsat_stats.csv')  
geemap.zonal_statistics(landsat, states, out_landsat_stats, statistics_type='SUM', scale=1000)

# %% [markdown]
# ## Compute zonal statistics for time-series images

# %%
Map = geemap.Map()

collection = ee.ImageCollection('MODIS/MCD43A4_006_NDVI') \
                  .filter(ee.Filter.date('2018-04-01', '2018-05-01')) \
                  .select("NDVI")\

vis_params = {
  'min': 0.0,
  'max': 1.0,
  'palette': [
    'FFFFFF', 'CE7E45', 'DF923D', 'F1B555', 'FCD163', '99B718', '74A901',
    '66A000', '529400', '3E8601', '207401', '056201', '004C00', '023B01',
    '012E01', '011D01', '011301'
  ],
}

first_image = collection.first()

Map.addLayer(first_image, vis_params, "First image")
Map.setCenter(-7.03125, 31.0529339857, 2)
Map
# Out:
# Map(center=[31.0529339857, -7.03125], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=H…

# %%
modis = collection.toBands()
Map.addLayer(modis, {}, "MODIS Time series", False)

# %%
out_landsat_stats = os.path.join(out_dir, 'ndvi.csv')  
geemap.zonal_statistics(modis, fc, out_landsat_stats, statistics_type='MEAN', scale=1000)

# %%
out_landsat_stats = os.path.join(out_dir, 'ndvi.csv')  
geemap.zonal_statistics(modis, fc, out_landsat_stats, statistics_type='MEAN', scale=1000)
# Out:
# Computing statistics ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/tables/b54d54fbc21ccd63ba0dd18c30136ca3-a16914be5818f95ec460de0232899e7d:getFeatures
# Please wait ...
# Data downloaded to /root/Downloads/ndvi.csv

# %% [markdown]
# # <font color = 'red'>**GEE Lesson 19 - Computing zonal statistics by group with Google Earth Engine**</font>

# %% [markdown]
# https://tutorials.geemap.org/Analysis/zonal_stats_by_group/

# %%
Map = geemap.Map()
Map
# Out:
# Map(center=[20, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(Togg…

# %% [markdown]
# ### Add NLCD data
#
# NLCD: USGS National Land Cover Database
#
# https://developers.google.com/earth-engine/datasets/catalog/USGS_NLCD_RELEASES_2016_REL

# %%
dataset = ee.Image('USGS/NLCD/NLCD2016')
landcover = ee.Image(dataset.select('landcover'))
Map.addLayer(landcover, {}, 'NLCD 2016')

states = ee.FeatureCollection("TIGER/2018/States")
Map.addLayer(states, {}, 'US States')

# %%
Map.add_legend(builtin_legend='NLCD')

# %% [markdown]
# ### Calculate land cover compostion of each US state

# %%
out_dir = os.path.expanduser('~/Downloads')
if not os.path.exists(out_dir):
    os.makedirs(out_dir)

# %%
nlcd_stats = os.path.join(out_dir, 'nlcd_stats_sum.csv')  
    
# statistics_type can be either 'SUM' or 'PERCENTAGE'
# denominator can be used to convert square meters to other areal units, such as square kilimeters
geemap.zonal_statistics_by_group(landcover, states, nlcd_stats, statistics_type='SUM', denominator=1000000, decimal_places=2)
# Out:
# Computing ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/tables/41a4a69f7137f14567112a2e87fe682a-20352693dd6f536b403c7c79a36a811f:getFeatures
# Please wait ...
# Data downloaded to /root/Downloads/nlcd_stats_sum.csv

# %%
nlcd_stats = os.path.join(out_dir, 'nlcd_stats_pct.csv')  
geemap.zonal_statistics_by_group(landcover, states, nlcd_stats, statistics_type='PERCENTAGE')

# %% [markdown]
# ## Analyzing Global Land Cover

# %% [markdown]
# ### Add MODIS global land cover data
#
# MCD12Q1.006 MODIS Land Cover Type Yearly Global 500m
#
# https://developers.google.com/earth-engine/datasets/catalog/MODIS_006_MCD12Q1

# %%
Map = geemap.Map()

landcover = ee.Image('MODIS/006/MCD12Q1/2019_01_01') \
    .select('LC_Type1')

igbpLandCoverVis = {
  'min': 1.0,
  'max': 17.0,
  'palette': [
    '05450a', '086a10', '54a708', '78d203', '009900', 'c6b044', 'dcd159',
    'dade48', 'fbff13', 'b6ff05', '27ff87', 'c24f44', 'a5a5a5', 'ff6d4c',
    '69fff8', 'f9ffa4', '1c0dff'
  ],
}

Map.setCenter(6.746, 46.529, 2)
Map.addLayer(landcover, igbpLandCoverVis, 'MODIS Land Cover')

countries = ee.FeatureCollection('users/giswqs/public/countries')
Map.addLayer(countries, {}, "Countries")

Map
# Out:
# Map(center=[46.529, 6.746], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(childr…

# %%
Map.add_legend(builtin_legend='MODIS/051/MCD12Q1')

# %%
out_dir = os.path.join(os.path.expanduser('~'), 'Downloads')
global_stats = os.path.join(out_dir, 'global_stats_sum.csv')  

# statistics_type can be either 'SUM' or 'PERCENTAGE'
# denominator can be used to convert square meters to other areal units, such as square kilimeters
geemap.zonal_statistics_by_group(landcover, countries, global_stats, statistics_type='SUM', denominator=1000000, decimal_places=2)
# Out:
# Computing ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/tables/c061c91667ae3f30db8b554aec90d228-f01b6489f976dbe72ef67bfce2535daa:getFeatures
# Please wait ...
# Data downloaded to /root/Downloads/global_stats_sum.csv
